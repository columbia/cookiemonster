# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
pio.renderers.default = "notebook"
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from utils import get_df, analyze_budget_consumption, plot_budget_consumption, analyze_bias, plot_bias
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = "ray/synthetic/budget_consumption_varying_conversions_rate"

# %%
# %%time
budgetdf = analyze_budget_consumption(path)
budgetdf
# Out:
# 0
# 1
# 0 Touched Users:2
#  13
# Max User id:  14
#  Conversion rate: 1.05
#  Impression rate: 0.16
#  Total users: 17
#  4Min epoch:  8
# Touched Users:1  1Max epoch:9
#   Max User id:181
# 110
#  Touched Users:  Conversion rate: 0.5 211
# 20000  Impression rate:Max User id:Touched Users:   2000012
# 0.120000   Conversion rate:Total users: Max User id:1.013
#    1Impression rate: 20000 0.1  Conversion rate:14
# Min epoch:Total users:   1.020000183   Impression rate: Min epoch: Max epoch: Touched Users:  5Touched Users:0.1 118
# 39999 Total users:Touched Users:1 Max epoch:   Max User id: 2000039999Max User id: 18  40000
# Max User id:Min epoch: 1  Conversion rate: 400001 Conversion rate:  0.5Max epoch: Conversion rate:   0.1Impression rate:180.5
#  Impression rate:0.1Impression rate:   Total users:0.10.1711     Total users:40000Total users:Touched Users:Touched Users:     40000Min epoch:11175663    Min epoch: 16910Max User id:Min epoch: Max User id:      1Max epoch: Touched Users:Touched Users:Touched Users:11   200000    Max epoch:18 2666726667175663Conversion rate:Max epoch:
#  Conversion rate:    18 Max User id:Max User id:Max User id:180.75
# 0.1
#   2000002666726667Impression rate:    Conversion rate:Conversion rate:Conversion rate:0.1    0.10.75Total users:0.75   Impression rate: Impression rate:200000 Impression rate:  Impression rate:0.1 14Min epoch:0.1  0.1  0.1 Total users: 1Total users: Touched Users: Total users:  Total users:  20000026667Max epoch: 126667   1  Min epoch:Min epoch:18Max User id: Min epoch:
# 1  Min epoch:1 1  1Max epoch:1  Max epoch:  Conversion rate:Max epoch: Max epoch: 18 18 0.25
# 1818
#
#
# Impression rate: 0.1 Total users: 1 Min epoch: 1 Max epoch: 18
# 12 Touched Users: 79759 Max User id: 80000 Conversion rate: 0.25 Impression rate: 0.1 Total users: 80000 Min epoch: 1 Max epoch: 18
# 13 Touched Users: 79759 Max User id: 80000 Conversion rate: 0.25 Impression rate: 0.1 Total users: 80000 Min epoch: 1 Max epoch: 18
# CPU times: user 20.1 s, sys: 5.04 s, total: 25.1 s
# Wall time: 54.3 s
#     queries_ran  destination  num_reports  max_avg_budget  avg_max_budget  \
# 0             1            1        79581        0.008954        0.008954
# 1             2            1        79632        0.017909        0.017909
# 2             3            1        80244        0.026863        0.026863
# 3             4            1        80595        0.035818        0.035818
# 4             5            1       159754        0.046052        0.046052
# ..          ...          ...          ...             ...             ...
# 15           16            1       320596        0.057565        0.093383
# 16           17            1       399980        0.066519        0.113850
# 17           18            1       399997        0.066519        0.113850
# 18           19            1       399999        0.066519        0.113850
# 19           20            1       400000        0.066519        0.113850
#
#     avg_avg_budget status        baseline conversion_rate impression_rate
# 0         0.008954     OK             ipa             1.0             0.1
# 1         0.017909     OK             ipa             1.0             0.1
# 2         0.026863     OK             ipa             1.0             0.1
# 3         0.035818     OK             ipa             1.0             0.1
# 4         0.046052     OK             ipa             1.0             0.1
# ..             ...    ...             ...             ...             ...
# 15        0.012331     OK  user_epoch_ara             0.1             0.1
# 16        0.015377     OK  user_epoch_ara             0.1             0.1
# 17        0.015378     OK  user_epoch_ara             0.1             0.1
# 18        0.015378     OK  user_epoch_ara             0.1             0.1
# 19        0.015378     OK  user_epoch_ara             0.1             0.1
#
# [300 rows x 10 columns]

# %%
plot_budget_consumption(budgetdf, facet_row="conversion_rate")

# %%
path = "ray/synthetic/budget_consumption_varying_impressions_rate_7"

# %%
# %%time
budgetdf = analyze_budget_consumption(path)
budgetdf
# Out:
# 0
# 1
# 2
# 31
#  Touched Users: 4
# 1 Max User id: 1 Conversion rate:5
#  1.0 Impression rate: 0.25 Total users:6
#  1 Min epoch: 1 Max epoch: 187
#
# 4 0Touched Users:  Touched Users:1  8
# 20000Max User id:  Max User id:1  20000Conversion rate:  9
# Conversion rate:1.0  1.0Impression rate:  0.1Impression rate:  10
# 0.25Total users:  1Total users:  Min epoch:20000  1Min epoch:11
#   Max epoch:261  18  Touched Users:
# Max epoch:12
# Touched Users:   20000181
#  Max User id:Max User id:  13
# 200001 3 Conversion rate:Conversion rate:   Touched Users:1.01.0   14
# Impression rate:Impression rate:20000   1.00.25 Max User id: Total users: Total users: 20000 1 20000 Conversion rate: Min epoch:Min epoch:   1.0511    Max epoch:Max epoch:Impression rate:Touched Users:  1818
#
# 200000.1 Max User id:  Total users:2000010   Conversion rate:20000Touched Users: 7  1.0  1Min epoch:Impression rate:  Touched Users:Max User id: 0.1   1120000Total users:   Conversion rate: Max User id: Max epoch:20000 1.0  20000 Min epoch:Impression rate: 18  Conversion rate:1
# 0.5   1.0128Max epoch:Total users:    Impression rate: 18Touched Users:1 Touched Users:
#  1.0Min epoch: 1  20000 Total users:1Max User id:   9 Max User id:20000 Max epoch: 1  20000 Min epoch:Touched Users:18 Conversion rate:
# Conversion rate:  20000 1.01  1.0 Max User id:Impression rate: Max epoch: Impression rate:  20000 18 1.00.75Conversion rate:
#    Total users:Total users:1.0   20000Impression rate: 1 Min epoch: 0.5 1 Min epoch: Total users: Max epoch: 1 20000 18 Max epoch:
# Min epoch:  181
#  Max epoch: 18
# 11 Touched Users: 20000 Max User id: 20000 Conversion rate: 1.0 Impression rate: 0.5 Total users: 20000 Min epoch: 1 Max epoch: 18
# 13 Touched Users: 20000 Max User id: 20000 Conversion rate: 1.0 Impression rate: 0.75 Total users: 20000 Min epoch: 1 Max epoch: 18
# 14 Touched Users: 20000 Max User id: 20000 Conversion rate:  1.0 Impression rate:0.75 Total users: 20000 Min epoch: 1 Max epoch: 18
# CPU times: user 20.1 s, sys: 4.38 s, total: 24.5 s
# Wall time: 45.2 s
#     queries_ran  destination  num_reports  max_avg_budget  avg_max_budget  \
# 0             1            1        79338        0.008954        0.008954
# 1             2            1        79367        0.017909        0.017909
# 2             3            1        80489        0.026863        0.026863
# 3             4            1        80877        0.035818        0.035818
# 4             5            1       159645        0.046052        0.046052
# ..          ...          ...          ...             ...             ...
# 15           16            1       320598        0.124084        0.165019
# 16           17            1       399992        0.144551        0.195720
# 17           18            1       399994        0.144551        0.195720
# 18           19            1       399998        0.144551        0.195720
# 19           20            1       400000        0.144551        0.195720
#
#     avg_avg_budget status        baseline conversion_rate impression_rate
# 0         0.008954     OK             ipa             1.0            0.25
# 1         0.017909     OK             ipa             1.0            0.25
# 2         0.026863     OK             ipa             1.0            0.25
# 3         0.035818     OK             ipa             1.0            0.25
# 4         0.046052     OK             ipa             1.0            0.25
# ..             ...    ...             ...             ...             ...
# 15        0.108324     OK  user_epoch_ara             1.0             0.1
# 16        0.135102     OK  user_epoch_ara             1.0             0.1
# 17        0.135102     OK  user_epoch_ara             1.0             0.1
# 18        0.135104     OK  user_epoch_ara             1.0             0.1
# 19        0.135105     OK  user_epoch_ara             1.0             0.1
#
# [300 rows x 10 columns]

# %%
plot_budget_consumption(budgetdf, facet_row="impression_rate")
