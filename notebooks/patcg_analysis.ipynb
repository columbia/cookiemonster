# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
pio.renderers.default = "notebook"
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from utils import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Attribution Window 7

# %%
path = "ray/patcg/varying_epoch_granularity_aw_7"
df = analyze_results(path, "bias")
plot_bias_rmsre(df, x_axis="num_days_per_epoch", log_y=False)
plot_bias_rmsre_cdf(df, epoch_size=7, log_y=True)

# %%
path = "ray/patcg/varying_epoch_granularity_aw_7"
df = analyze_results(path, "budget")
plot_budget_consumption_lines(df, facet_row="num_days_per_epoch", height=1600)
plot_budget_consumption_bars(df, x_axis="num_days_per_epoch")

# %% [markdown]
# ### Attribution Window 14

# %%
path = "ray/patcg/varying_epoch_granularity_aw_14"
df = analyze_results(path, "bias")
plot_bias_rmsre(df, x_axis="num_days_per_epoch", log_y=False)
plot_bias_rmsre_cdf(df, epoch_size=7, log_y=True)

# %% [markdown]
# ### Attribution Window 30
