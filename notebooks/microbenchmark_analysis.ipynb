# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
pio.renderers.default = "notebook"
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from utils import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = "ray/microbenchmark/budget_consumption_varying_knob1"
df = analyze_results(path, "budget")
plot_budget_consumption_lines(df, facet_row="knob1")
plot_budget_consumption_bars(df, x_axis="knob1")

# %%
path = "ray/microbenchmark/varying_knob2"
df = analyze_results(path, "budget")
plot_budget_consumption_lines(df, facet_row="knob2")
plot_budget_consumption_bars(df, "knob2")

# %%
path = "ray/microbenchmark/budget_consumption_varying_knob1"
df = analyze_results(path, "bias")
plot_bias_avg_rmsre(df, x_axis="num_days_per_epoch", log_y=False)
plot_bias_rmsre_cdf(df)
# Out:
#    num_days_per_epoch        baseline  destination  avg_rmsre
# 0                   7   cookiemonster            1    0.01585
# 1                   7             ipa            1    0.01585
# 2                   7  user_epoch_ara            1    0.01585
