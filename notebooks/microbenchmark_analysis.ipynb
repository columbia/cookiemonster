# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import plotly.io as pio

pio.renderers.default = "notebook"
import plotly.offline as pyo

pyo.init_notebook_mode(connected=True)
from utils import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = "ray/microbenchmark/varying_knob1"
plot_budget_consumption_lines(path, facet_row="knob1", height=1200)
plot_budget_consumption_bars(path, x_axis="knob1", log_y=True)

# %%
path = "ray/microbenchmark/varying_knob2"
plot_budget_consumption_lines(path, facet_row="knob2", height=600)
plot_budget_consumption_bars(path, x_axis="knob2", log_y=True, height=400)

# %%
path = "ray/microbenchmark/varying_knob1"
plot_bias_rmsre(path, x_axis="num_days_per_epoch", log_y=False)
plot_bias_rmsre_cdf(path)

# %%
path = "ray/microbenchmark/varying_knob1"
plot_budget_consumption_cdf(path)
