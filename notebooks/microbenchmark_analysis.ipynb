# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
pio.renderers.default = "notebook"
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from utils import get_df, analyze_results, plot_budget_consumption_lines, plot_budget_consumption_bars, plot_accuracy
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = "ray/synthetic/budget_consumption_varying_knob1"
df = analyze_results(path, "budget")
plot_budget_consumption_lines(df, facet_row="knob1")
plot_budget_consumption_bars(df, "knob1")

# %%
path = "ray/synthetic/budget_consumption_varying_knob2"
df = analyze_results(path, "budget")
plot_budget_consumption_lines(df, facet_row="knob2")
plot_budget_consumption_bars(df, "knob2")

# %%
# path = "ray/synthetic/budget_consumption_varying_epoch_granularity"
# df = analyze_results(path, "budget")
# plot_budget_consumption(df, facet_row="num_days_per_epoch")

# %%
path = "ray/synthetic/bias_varying_workload_size1"
df = analyze_results(path, "bias")
plot_accuracy(df)

# %%
path = "ray/synthetic/bias_varying_workload_size2"
df = analyze_results(path, "bias")
plot_accuracy(df)
