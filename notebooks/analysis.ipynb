# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
pio.renderers.default = "notebook"
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from utils import get_df, analyze_budget_consumption, plot_budget_consumption, analyze_bias, plot_bias
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = "ray/synthetic/budget_consumption_varying_conversions_rate"
budgetdf = analyze_budget_consumption(path)
plot_budget_consumption(budgetdf, facet_row="conversion_rate")

# %%
path = "ray/synthetic/budget_consumption_varying_impressions_rate_7"
budgetdf = analyze_budget_consumption(path)
plot_budget_consumption(budgetdf, facet_row="impression_rate")

# %%
path = "ray/synthetic/budget_consumption_varying_epoch_granularity"
budgetdf = analyze_budget_consumption(path)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 64
#  Touched Users: 7
# 1 Max User id: 18
#  Conversion rate: 1.0 Impression rate: 0.19
#  Total users: 1 Min epoch: 1 10
# Max epoch: 120
# 7 Touched Users: 1 Max User id:11
#  1 Conversion rate: 81.0  Touched Users:Impression rate:  12
# 10.1  Max User id:Total users:  11  Min epoch: 13
# Conversion rate:1  1.0Max epoch:  Impression rate:18
# 0.1 Total users: 14
# 1 Min epoch: 1 Max epoch: 6
# 1 Touched Users: 20000 Max User id: 20000 Conversion rate: 1.0 Impression rate:11  0.1Touched Users:  Total users:1  20000Max User id:  2Min epoch: 1 1Touched Users:   Max epoch:20000 Conversion rate:18
# ...

# %%
plot_budget_consumption(budgetdf, facet_row="num_days_per_epoch")
